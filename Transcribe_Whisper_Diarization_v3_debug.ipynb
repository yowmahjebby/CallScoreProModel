# %% [markdown]
# ###### conda install: ffmpeg

# %%
# !pip install pydantic==1.10.8 #need to upgrade to successfully import pyannote audio

# %%
# !pip install -q git+https://github.com/pyannote/pyannote-audio.git #for diarization
# !pip install -q git+https://github.com/openai/whisper.git #for transcription
# !pip install protobuf==3.20.* #need to downgrade protobuf for pyannote to work

# %%
import whisper
import subprocess
import torch
import wave
import contextlib

# %%
#run this cell twice if first results to error
import pyannote.audio

from pyannote.audio import Audio
from pyannote.core import Segment

# %%
import ffmpeg
import os
import pandas as pd
from pydub import AudioSegment

# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
import datetime as dt
from datetime import timedelta

# %% [markdown]
# ### Convert mp3,m4a,ogg,flac to wav
# ##### Input: audio file path
# ##### Output: wav file path

# %%
def prepare_voice_file(path: str) -> str:
    """
    Converts the input audio file to WAV format if necessary and returns the path to the WAV file.
    """
    if os.path.splitext(path)[1] == '.wav':
        return path
    elif os.path.splitext(path)[1] in ('.mp3', '.m4a', '.ogg', '.flac'):
        audio_file = AudioSegment.from_file(
            path, format=os.path.splitext(path)[1][1:])
        audio_file=audio_file.set_channels(1)
        wav_file = os.path.splitext(path)[0] + '.wav'
        audio_file.export(wav_file, format='wav')
        return wav_file
    else:
        raise ValueError(
            f'Unsupported audio format: {format(os.path.splitext(path)[1])}')

# %%
# wav_file=prepare_voice_file(r"D:\Downloads\mara_PSMDS\Call_Center_Conversation_(chargeback_refund)_(192_kbps).mp3")

# %% [markdown]
# ### Transcription
# ##### Input: wav file path
# ##### Output: model transcription

# %%
#define other parameters for trancscriber: use small model for English only

#num_speakers = 2 #@param {type:"integer"}

language = 'English' #@param ['any', 'English']

#model_size = 'large' #@param ['tiny', 'base', 'small', 'medium', 'large']
model_size = 'small' #@param ['tiny', 'base', 'small', 'medium', 'large']

model_name = model_size
if language == 'English' and model_size != 'large':
  model_name += '.en'

model = whisper.load_model('model_size') #use small model for English only

# %%
def transcribe(wav_file: str):
    result=model.transcribe(wav_file)
    return(result)

# %%
#result=transcribe(wav_file)
#result['text']

# %% [markdown]
# ### Speaker diarization
# ##### Input: wav file path, result from transcription
# ##### Output: dataframe with speaker, text and time stamp

# %%
#use embedding and clustering for speaker diarization
from pyannote.audio.pipelines.speaker_verification import PretrainedSpeakerEmbedding
embedding_model = PretrainedSpeakerEmbedding(
    "pyannote/embedding", use_auth_token='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')
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.2.7 to v2.2.0.post0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\kim\.cache\torch\pyannote\models--pyannote--embedding\snapshots\c6335d8f1cd77b30084387468a6cf26fea90009b\pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.8.1+cu102, yours is 2.2.1+cpu. Bad things might happen unless you revert torch to 1.x.

# %%
def diarize(wav_file, result):
    audio=Audio()
    segments=result["segments"]
    #get audio framerate and duration
    with contextlib.closing(wave.open(wav_file,'r')) as f:
        frames = f.getnframes()
        rate = f.getframerate()
        duration = frames / float(rate)

    #embed passed audio segment ---> revisit for real-time use case
    def segment_embedding(segment):
        start = segment["start"]
        # Whisper overshoots the end timestamp in the last segment
        end = min(duration, segment["end"])
        # diarization results to error when input segment is too short
        if(end-start<0.1): end=end+(0.1-(end-start))
        clip = Segment(start, end)
        waveform, sample_rate = audio.crop(wav_file, clip)
        return embedding_model(waveform[None])

    embeddings = np.zeros(shape=(len(segments), len(segment_embedding(segments[0])[0])))
    for i, segment in enumerate(segments):
        embeddings[i] = segment_embedding(segment)

    embeddings = np.nan_to_num(embeddings)

    #clustering for speaker identification
    clustering = AgglomerativeClustering(2).fit(embeddings)
    labels = clustering.labels_
    for i in range(len(segments)):
        segments[i]["speaker"] = 'SPEAKER ' + str(labels[i] + 1)

    #create dataframe with speaker, text and time stamp
    def time(secs):
        return pd.to_datetime(pd.to_datetime(round(segment['start']),unit='s'),unit='m').strftime('%H:%M:%S')

    transcription_=[]
    for (i, segment) in enumerate(segments):
        transcription_.append(dict(zip(['Speaker','Text','Time start','Time end'],[segment['speaker'],segment['text'],time(segment['start']),time(segment['end'])])))
    df_transcript=pd.DataFrame(transcription_)

    j=0
    i=0
    f_transcript=[]
#merge data of same speaker in consecutive rows
    while i<df_transcript.shape[0]-1:
        j=i+1
        d=df_transcript['Text'][i]
        while(df_transcript['Speaker'][i]==df_transcript['Speaker'][j])&(j<df_transcript.shape[0]-1):
            a=df_transcript['Speaker'][i]
            b=df_transcript['Time start'][i]
            c=df_transcript['Time end'][j]
            d=d+df_transcript['Text'][j]
            j=j+1
        if(j-i==1):
            a=df_transcript['Speaker'][i]
            b=df_transcript['Time start'][i]
            c=df_transcript['Time end'][i]
            d=df_transcript['Text'][i]
        f_transcript.append(dict(zip(['Speaker','Text','Time Start','Time End'],[a,d,b,c])))
        i=j
#for last index
    a=df_transcript['Speaker'][i]
    b=df_transcript['Time start'][i]
    c=df_transcript['Time end'][j]
    d=df_transcript['Text'][i]
    f_transcript.append(dict(zip(['Speaker','Text','Time Start','Time End'],[a,d,b,c])))

    if(f_transcript[-1]['Speaker']==f_transcript[-2]['Speaker']):
        f_transcript[-2]['Text']=f_transcript[-2]['Text']+(f_transcript[-1]['Text'])
        f_transcript[-2]['Time End']=f_transcript[-1]['Time End']
        f_transcript.pop()
    return pd.DataFrame(f_transcript)

# %%
#transcript=diarize(wav_file, result)
#transcript

# %%
def makecsv(wav_file, transcript):
    filename=os.path.splitext(os.path.basename(wav_file))[0]
    transcript.to_csv(filename+'.csv')

# %%
#makecsv(wav_file, transcript)

# %% [markdown]
# ### Next: define "transcribe" function, write to csv using audio filename, loop for all mp3 files in folder, apply NER

# %%
#transcription pipeline:
#prepare wav file
wav_file=prepare_voice_file(r"D:\Downloads\mara_PSMDS\Call_Center_Conversation_(chargeback_refund)_(192_kbps).mp3")
#transcribe wav file
result=transcribe(wav_file)
#diarization
transcript=diarize(wav_file, result)
#write to csv
makecsv(wav_file, transcript)

# %% [markdown]
# ### Code ni Lei

# %%
#loop for all mp3 files in folder
import os
import speech_recognition as sr
import pandas as pd
import spacy

# Load English NER model
nlp = spacy.load("en_core_web_sm")

# Initialize the recognizer
r = sr.Recognizer()

# List to store data for all call recordings
data = []

# Directory containing all audio files
directory = "D:\Downloads\mara_PSMDS\Recordings"

# Iterate over each audio file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".wav"):
        filepath = os.path.join(directory, filename)
        print("Processing:", filename)

        # Load audio file
        audio = False
        with sr.AudioFile(filepath) as source:
            audio = r.record(source)

        # Recognize speech
        try:
            s = r.recognize_google(audio)

            # Perform Named Entity Recognition
            doc = nlp(s)
            entities = [(ent.text, ent.label_) for ent in doc.ents]

            # Append data to the list
            data.append({'Filename': filename, 'Text': s, 'Entities': entities})

        except Exception as e:
            print("Exception:", str(e))

# Create a DataFrame from the collected data
df = pd.DataFrame(data)

# Print the DataFrame
print(df.head())

# %% [markdown]
# ### Code with Loop for all recordings

# %%
directory="D:\Downloads\mara_PSMDS\Recordings"

for filename in os.listdir(directory):
    if os.path.splitext(filename)[1] in ('.mp3', '.m4a', '.ogg', '.flac'):
        wav_file=prepare_voice_file(os.path.join(directory,filename))
        #transcribe wav file
        result=transcribe(wav_file)
        #diarization
        transcript=diarize(wav_file, result)
        #write to csv
        makecsv(wav_file, transcript)

# %%
result['segments']
# Out:
# [{'id': 0,
#   'seek': 0,
#   'start': 0.0,
#   'end': 10.0,
#   'text': ' Thank you for calling Coats and Gounds, my name is Sam, how can I help you?',
#   'tokens': [50364,
#    1044,
#    291,
#    337,
#    5141,
#    3066,
#    1720,
#    293,
#    460,
#    4432,
#    11,
#    452,
#    1315,
#    307,
#    4832,
#    11,
#    577,
#    393,
#    286,
#    854,
#    291,
#    30,
#    50864],
#   'temperature': 0.0,
#   'avg_logprob': -0.3494122603843952,
#   'compression_ratio': 1.3133333333333332,
#   'no_speech_prob': 0.11384373903274536},
#  {'id': 1,
#   'seek': 0,
#   'start': 10.0,
#   'end': 20.240000000000002,
#   'text': ' Oh yes, I bought a coat from you guys but I need to return it because it was the wrong',
#   'tokens': [50864,
#    876,
#    2086,
#    11,
#    286,
#    4243,
#    257,
#    10690,
#    490,
#    291,
#    1074,
#    457,
#    286,
#    643,
#    281,
#    2736,
#    309,
#    570,
#    309,
#    390,
#    264,
#    2085,
#    51376],
#   'temperature': 0.0,
#   'avg_logprob': -0.3494122603843952,
#   'compression_ratio': 1.3133333333333332,
#   'no_speech_prob': 0.11384373903274536},
#  {'id': 2,
#   'seek': 0,
#   'start': 20.240000000000002,
#   'end': 24.32,
#   'text': ' size and my size is not available.',
#   'tokens': [51376, 2744, 293, 452, 2744, 307, 406, 2435, 13, 51580],
#   'temperature': 0.0,
#   'avg_logprob': -0.3494122603843952,
#   'compression_ratio': 1.3133333333333332,
#   'no_speech_prob': 0.11384373903274536},
#  {'id': 3,
#   'seek': 2432,
#   'start': 24.32,
#   'end': 30.560000000000002,
#   'text': " I haven't received any email from you and I wonder if my payment has been refunded.",
#   'tokens': [50364,
#    286,
#    2378,
#    380,
#    4613,
#    604,
#    3796,
#    490,
#    291,
#    293,
#    286,
#    2441,
#    498,
#    452,
#    10224,
#    575,
#    668,
#    29384,
#    292,
#    13,
#    50676],
#   'temperature': 0.0,
#   'avg_logprob': -0.3221027638652537,
#   'compression_ratio': 1.5319148936170213,
#   'no_speech_prob': 0.580710768699646},
#  {'id': 4,
#   'seek': 2432,
#   'start': 30.560000000000002,
#   'end': 33.28,
#   'text': ' Seems like it does not apply to my account yet.',
#   'tokens': [50676,
#    22524,
#    411,
#    309,
#    775,
#    406,
#    3079,
#    281,
#    452,
#    2696,
#    1939,
#    13,
#    50812],
#   'temperature': 0.0,
#   'avg_logprob': -0.3221027638652537,
#   'compression_ratio': 1.5319148936170213,
#   'no_speech_prob': 0.580710768699646},
#  {'id': 5,
#   'seek': 2432,
#   'start': 33.28,
#   'end': 36.88,
#   'text': ' I do apologize for the inconvenience but let me go ahead and check if there are some',
#   'tokens': [50812,
#    286,
#    360,
#    12328,
#    337,
#    264,
#    28752,
#    1182,
#    457,
#    718,
#    385,
#    352,
#    2286,
#    293,
#    1520,
#    498,
#    456,
#    366,
#    512,
#    50992],
#   'temperature': 0.0,
#   'avg_logprob': -0.3221027638652537,
#   'compression_ratio': 1.5319148936170213,
#   'no_speech_prob': 0.580710768699646},
#  {'id': 6,
#   'seek': 2432,
#   'start': 36.88,
#   'end': 39.36,
#   'text': ' notes in the order details.',
#   'tokens': [50992, 5570, 294, 264, 1668, 4365, 13, 51116],
#   'temperature': 0.0,
#   'avg_logprob': -0.3221027638652537,
#   'compression_ratio': 1.5319148936170213,
#   'no_speech_prob': 0.580710768699646},
#  {'id': 7,
#   'seek': 2432,
#   'start': 39.36,
#   'end': 43.120000000000005,
#   'text': ' May I ask for the original online order number?',
#   'tokens': [51116,
#    1891,
#    286,
#    1029,
#    337,
#    264,
#    3380,
#    2950,
#    1668,
#    1230,
#    30,
#    51304],
#   'temperature': 0.0,
#   'avg_logprob': -0.3221027638652537,
#   'compression_ratio': 1.5319148936170213,
#   'no_speech_prob': 0.580710768699646},
#  {'id': 8,
#   'seek': 2432,
#   'start': 43.120000000000005,
#   'end': 44.44,
#   'text': ' Okay, let me see.',
#   'tokens': [51304, 1033, 11, 718, 385, 536, 13, 51370],
#   'temperature': 0.0,
#   'avg_logprob': -0.3221027638652537,
#   'compression_ratio': 1.5319148936170213,
#   'no_speech_prob': 0.580710768699646},
#  {'id': 9,
#   'seek': 2432,
#   'start': 44.44,
#   'end': 47.519999999999996,
#   'text': ' Alright, please wait for a moment.',
#   'tokens': [51370, 2798, 11, 1767, 1699, 337, 257, 1623, 13, 51524],
#   'temperature': 0.0,
#   'avg_logprob': -0.3221027638652537,
#   'compression_ratio': 1.5319148936170213,
#   'no_speech_prob': 0.580710768699646},
#  {'id': 10,
#   'seek': 2432,
#   'start': 47.519999999999996,
#   'end': 49.28,
#   'text': ' Okay, hold on.',
#   'tokens': [51524, 1033, 11, 1797, 322, 13, 51612],
#   'temperature': 0.0,
#   'avg_logprob': -0.3221027638652537,
#   'compression_ratio': 1.5319148936170213,
#   'no_speech_prob': 0.580710768699646},
#  {'id': 11,
#   'seek': 4928,
#   'start': 49.28,
#   'end': 56.28,
#   'text': " Okay, I believe it's 017 1425 793.",
#   'tokens': [50364,
#    1033,
#    11,
#    286,
#    1697,
#    309,
#    311,
#    1958,
#    7773,
#    3499,
#    6074,
#    1614,
#    26372,
#    13,
#    50714],
#   'temperature': 0.0,
#   'avg_logprob': -0.2524656355381012,
#   'compression_ratio': 1.2820512820512822,
#   'no_speech_prob': 0.016675744205713272},
#  {'id': 12,
#   'seek': 4928,
#   'start': 56.28,
#   'end': 57.28,
#   'text': ' Thank you.',
#   'tokens': [50714, 1044, 291, 13, 50764],
#   'temperature': 0.0,
#   'avg_logprob': -0.2524656355381012,
#   'compression_ratio': 1.2820512820512822,
#   'no_speech_prob': 0.016675744205713272},
#  {'id': 13,
#   'seek': 4928,
#   'start': 57.28,
#   'end': 63.28,
#   'text': ' Just to verify that 017 1425 793, correct?',
#   'tokens': [50764,
#    1449,
#    281,
#    16888,
#    300,
#    1958,
#    7773,
#    3499,
#    6074,
#    1614,
#    26372,
#    11,
#    3006,
#    30,
#    51064],
#   'temperature': 0.0,
#   'avg_logprob': -0.2524656355381012,
#   'compression_ratio': 1.2820512820512822,
#   'no_speech_prob': 0.016675744205713272},
#  {'id': 14,
#   'seek': 4928,
#   'start': 63.28,
#   'end': 65.28,
#   'text': " Yes, that's right.",
#   'tokens': [51064, 1079, 11, 300, 311, 558, 13, 51164],
#   'temperature': 0.0,
#   'avg_logprob': -0.2524656355381012,
#   'compression_ratio': 1.2820512820512822,
#   'no_speech_prob': 0.016675744205713272},
#  {'id': 15,
#   'seek': 4928,
#   'start': 65.28,
#   'end': 71.92,
#   'text': ' I do apologize but the one that you provided is actually not accepting towards our database.',
#   'tokens': [51164,
#    286,
#    360,
#    12328,
#    457,
#    264,
#    472,
#    300,
#    291,
#    5649,
#    307,
#    767,
#    406,
#    17391,
#    3030,
#    527,
#    8149,
#    13,
#    51496],
#   'temperature': 0.0,
#   'avg_logprob': -0.2524656355381012,
#   'compression_ratio': 1.2820512820512822,
#   'no_speech_prob': 0.016675744205713272},
#  {'id': 16,
#   'seek': 7192,
#   'start': 71.92,
#   'end': 80.72,
#   'text': ' Do you actually have a number that starts with 07 or 7 or can I ask for your first and',
#   'tokens': [50364,
#    1144,
#    291,
#    767,
#    362,
#    257,
#    1230,
#    300,
#    3719,
#    365,
#    1958,
#    22,
#    420,
#    1614,
#    420,
#    393,
#    286,
#    1029,
#    337,
#    428,
#    700,
#    293,
#    50804],
#   'temperature': 0.0,
#   'avg_logprob': -0.29349009195963544,
#   'compression_ratio': 1.4464285714285714,
#   'no_speech_prob': 0.5152469873428345},
#  {'id': 17,
#   'seek': 7192,
#   'start': 80.72,
#   'end': 83.4,
#   'text': ' last name so I can manually check it in our database?',
#   'tokens': [50804,
#    1036,
#    1315,
#    370,
#    286,
#    393,
#    16945,
#    1520,
#    309,
#    294,
#    527,
#    8149,
#    30,
#    50938],
#   'temperature': 0.0,
#   'avg_logprob': -0.29349009195963544,
#   'compression_ratio': 1.4464285714285714,
#   'no_speech_prob': 0.5152469873428345},
#  {'id': 18,
#   'seek': 7192,
#   'start': 83.4,
#   'end': 88.28,
#   'text': " Yeah, I'm not sure about a 07 or 3.0 something.",
#   'tokens': [50938,
#    865,
#    11,
#    286,
#    478,
#    406,
#    988,
#    466,
#    257,
#    1958,
#    22,
#    420,
#    805,
#    13,
#    15,
#    746,
#    13,
#    51182],
#   'temperature': 0.0,
#   'avg_logprob': -0.29349009195963544,
#   'compression_ratio': 1.4464285714285714,
#   'no_speech_prob': 0.5152469873428345},
#  {'id': 19,
#   'seek': 7192,
#   'start': 88.28,
#   'end': 89.92,
#   'text': " Anyway, it's Adam Wilson.",
#   'tokens': [51182, 5684, 11, 309, 311, 7938, 15388, 13, 51264],
#   'temperature': 0.0,
#   'avg_logprob': -0.29349009195963544,
#   'compression_ratio': 1.4464285714285714,
#   'no_speech_prob': 0.5152469873428345},
#  {'id': 20,
#   'seek': 7192,
#   'start': 89.92,
#   'end': 91.44,
#   'text': ' Alright, thank you.',
#   'tokens': [51264, 2798, 11, 1309, 291, 13, 51340],
#   'temperature': 0.0,
#   'avg_logprob': -0.29349009195963544,
#   'compression_ratio': 1.4464285714285714,
#   'no_speech_prob': 0.5152469873428345},
#  {'id': 21,
#   'seek': 7192,
#   'start': 91.44,
#   'end': 101.08,
#   'text': ' So Wilson is spelled as W for whiskey, I for India, L for Lima, S for Sierra, O for Oscar',
#   'tokens': [51340,
#    407,
#    15388,
#    307,
#    34388,
#    382,
#    343,
#    337,
#    34648,
#    11,
#    286,
#    337,
#    5282,
#    11,
#    441,
#    337,
#    50217,
#    11,
#    318,
#    337,
#    25182,
#    11,
#    422,
#    337,
#    20718,
#    51822],
#   'temperature': 0.0,
#   'avg_logprob': -0.29349009195963544,
#   'compression_ratio': 1.4464285714285714,
#   'no_speech_prob': 0.5152469873428345},
#  {'id': 22,
#   'seek': 10108,
#   'start': 101.08,
#   'end': 102.39999999999999,
#   'text': ' and for November.',
#   'tokens': [50364, 293, 337, 7674, 13, 50430],
#   'temperature': 0.0,
#   'avg_logprob': -0.2809013639177595,
#   'compression_ratio': 1.4956521739130435,
#   'no_speech_prob': 0.13999325037002563},
#  {'id': 23,
#   'seek': 10108,
#   'start': 102.39999999999999,
#   'end': 103.8,
#   'text': ' Is that correct Adam?',
#   'tokens': [50430, 1119, 300, 3006, 7938, 30, 50500],
#   'temperature': 0.0,
#   'avg_logprob': -0.2809013639177595,
#   'compression_ratio': 1.4956521739130435,
#   'no_speech_prob': 0.13999325037002563},
#  {'id': 24,
#   'seek': 10108,
#   'start': 103.8,
#   'end': 104.8,
#   'text': ' Yes.',
#   'tokens': [50500, 1079, 13, 50550],
#   'temperature': 0.0,
#   'avg_logprob': -0.2809013639177595,
#   'compression_ratio': 1.4956521739130435,
#   'no_speech_prob': 0.13999325037002563},
#  {'id': 25,
#   'seek': 10108,
#   'start': 104.8,
#   'end': 106.6,
#   'text': ' Alright, thank you for that information.',
#   'tokens': [50550, 2798, 11, 1309, 291, 337, 300, 1589, 13, 50640],
#   'temperature': 0.0,
#   'avg_logprob': -0.2809013639177595,
#   'compression_ratio': 1.4956521739130435,
#   'no_speech_prob': 0.13999325037002563},
#  {'id': 26,
#   'seek': 10108,
#   'start': 106.6,
#   'end': 111.03999999999999,
#   'text': ' Okay, let me just quickly log into a portal and check any notes in your order.',
#   'tokens': [50640,
#    1033,
#    11,
#    718,
#    385,
#    445,
#    2661,
#    3565,
#    666,
#    257,
#    14982,
#    293,
#    1520,
#    604,
#    5570,
#    294,
#    428,
#    1668,
#    13,
#    50862],
#   'temperature': 0.0,
#   'avg_logprob': -0.2809013639177595,
#   'compression_ratio': 1.4956521739130435,
#   'no_speech_prob': 0.13999325037002563},
#  {'id': 27,
#   'seek': 10108,
#   'start': 111.03999999999999,
#   'end': 118.4,
#   'text': ' Do you still have the return tracking from the courier company when you return the item?',
#   'tokens': [50862,
#    1144,
#    291,
#    920,
#    362,
#    264,
#    2736,
#    11603,
#    490,
#    264,
#    1005,
#    811,
#    2237,
#    562,
#    291,
#    2736,
#    264,
#    3174,
#    30,
#    51230],
#   'temperature': 0.0,
#   'avg_logprob': -0.2809013639177595,
#   'compression_ratio': 1.4956521739130435,
#   'no_speech_prob': 0.13999325037002563},
#  {'id': 28,
#   'seek': 10108,
#   'start': 118.4,
#   'end': 119.4,
#   'text': ' Not sure.',
#   'tokens': [51230, 1726, 988, 13, 51280],
#   'temperature': 0.0,
#   'avg_logprob': -0.2809013639177595,
#   'compression_ratio': 1.4956521739130435,
#   'no_speech_prob': 0.13999325037002563},
#  {'id': 29,
#   'seek': 10108,
#   'start': 119.4,
#   'end': 123.92,
#   'text': ' Is it the 74391?',
#   'tokens': [51280, 1119, 309, 264, 1614, 17201, 29925, 30, 51506],
#   'temperature': 0.0,
#   'avg_logprob': -0.2809013639177595,
#   'compression_ratio': 1.4956521739130435,
#   'no_speech_prob': 0.13999325037002563},
#  {'id': 30,
#   'seek': 10108,
#   'start': 123.92,
#   'end': 127.96,
#   'text': " That's actually the return authorization from Coats and Gounds.",
#   'tokens': [51506,
#    663,
#    311,
#    767,
#    264,
#    2736,
#    33697,
#    490,
#    3066,
#    1720,
#    293,
#    460,
#    4432,
#    13,
#    51708],
#   'temperature': 0.0,
#   'avg_logprob': -0.2809013639177595,
#   'compression_ratio': 1.4956521739130435,
#   'no_speech_prob': 0.13999325037002563},
#  {'id': 31,
#   'seek': 12796,
#   'start': 127.96,
#   'end': 132.28,
#   'text': ' When you return the item to the courier company for shipping, they should have provided you',
#   'tokens': [50364,
#    1133,
#    291,
#    2736,
#    264,
#    3174,
#    281,
#    264,
#    1005,
#    811,
#    2237,
#    337,
#    14122,
#    11,
#    436,
#    820,
#    362,
#    5649,
#    291,
#    50580],
#   'temperature': 0.0,
#   'avg_logprob': -0.2002505206186837,
#   'compression_ratio': 1.6378600823045268,
#   'no_speech_prob': 0.05554485321044922},
#  {'id': 32,
#   'seek': 12796,
#   'start': 132.28,
#   'end': 133.56,
#   'text': ' with the return tracking.',
#   'tokens': [50580, 365, 264, 2736, 11603, 13, 50644],
#   'temperature': 0.0,
#   'avg_logprob': -0.2002505206186837,
#   'compression_ratio': 1.6378600823045268,
#   'no_speech_prob': 0.05554485321044922},
#  {'id': 33,
#   'seek': 12796,
#   'start': 133.56,
#   'end': 135.68,
#   'text': ' Do you still have that?',
#   'tokens': [50644, 1144, 291, 920, 362, 300, 30, 50750],
#   'temperature': 0.0,
#   'avg_logprob': -0.2002505206186837,
#   'compression_ratio': 1.6378600823045268,
#   'no_speech_prob': 0.05554485321044922},
#  {'id': 34,
#   'seek': 12796,
#   'start': 135.68,
#   'end': 139.32,
#   'text': " It's actually printed in the upper right part of the receipt.",
#   'tokens': [50750,
#    467,
#    311,
#    767,
#    13567,
#    294,
#    264,
#    6597,
#    558,
#    644,
#    295,
#    264,
#    33882,
#    13,
#    50932],
#   'temperature': 0.0,
#   'avg_logprob': -0.2002505206186837,
#   'compression_ratio': 1.6378600823045268,
#   'no_speech_prob': 0.05554485321044922},
#  {'id': 35,
#   'seek': 12796,
#   'start': 139.32,
#   'end': 143.76,
#   'text': ' Okay, I probably have to dig it up.',
#   'tokens': [50932, 1033, 11, 286, 1391, 362, 281, 2528, 309, 493, 13, 51154],
#   'temperature': 0.0,
#   'avg_logprob': -0.2002505206186837,
#   'compression_ratio': 1.6378600823045268,
#   'no_speech_prob': 0.05554485321044922},
#  {'id': 36,
#   'seek': 12796,
#   'start': 143.76,
#   'end': 151.2,
#   'text': ' Okay, I imagine I have it somewhere but it might take some time to look for that.',
#   'tokens': [51154,
#    1033,
#    11,
#    286,
#    3811,
#    286,
#    362,
#    309,
#    4079,
#    457,
#    309,
#    1062,
#    747,
#    512,
#    565,
#    281,
#    574,
#    337,
#    300,
#    13,
#    51526],
#   'temperature': 0.0,
#   'avg_logprob': -0.2002505206186837,
#   'compression_ratio': 1.6378600823045268,
#   'no_speech_prob': 0.05554485321044922},
#  {'id': 37,
#   'seek': 12796,
#   'start': 151.2,
#   'end': 152.92,
#   'text': ' Oh, I see.',
#   'tokens': [51526, 876, 11, 286, 536, 13, 51612],
#   'temperature': 0.0,
#   'avg_logprob': -0.2002505206186837,
#   'compression_ratio': 1.6378600823045268,
#   'no_speech_prob': 0.05554485321044922},
#  {'id': 38,
#   'seek': 12796,
#   'start': 152.92,
#   'end': 156.07999999999998,
#   'text': ' Anyway, I tried to search for your name and nothing is coming up.',
#   'tokens': [51612,
#    5684,
#    11,
#    286,
#    3031,
#    281,
#    3164,
#    337,
#    428,
#    1315,
#    293,
#    1825,
#    307,
#    1348,
#    493,
#    13,
#    51770],
#   'temperature': 0.0,
#   'avg_logprob': -0.2002505206186837,
#   'compression_ratio': 1.6378600823045268,
#   'no_speech_prob': 0.05554485321044922},
#  {'id': 39,
#   'seek': 15608,
#   'start': 156.08,
#   'end': 160.04000000000002,
#   'text': ' Can I ask for the order under your name originally?',
#   'tokens': [50364,
#    1664,
#    286,
#    1029,
#    337,
#    264,
#    1668,
#    833,
#    428,
#    1315,
#    7993,
#    30,
#    50562],
#   'temperature': 0.0,
#   'avg_logprob': -0.3408244560504782,
#   'compression_ratio': 1.4325842696629214,
#   'no_speech_prob': 0.34106191992759705},
#  {'id': 40,
#   'seek': 15608,
#   'start': 160.04000000000002,
#   'end': 163.32000000000002,
#   'text': ' Yes, yes, enter my name.',
#   'tokens': [50562, 1079, 11, 2086, 11, 3242, 452, 1315, 13, 50726],
#   'temperature': 0.0,
#   'avg_logprob': -0.3408244560504782,
#   'compression_ratio': 1.4325842696629214,
#   'no_speech_prob': 0.34106191992759705},
#  {'id': 41,
#   'seek': 15608,
#   'start': 163.32000000000002,
#   'end': 166.72000000000003,
#   'text': " So it's not under Andy or something, it's Adam?",
#   'tokens': [50726,
#    407,
#    309,
#    311,
#    406,
#    833,
#    13285,
#    420,
#    746,
#    11,
#    309,
#    311,
#    7938,
#    30,
#    50896],
#   'temperature': 0.0,
#   'avg_logprob': -0.3408244560504782,
#   'compression_ratio': 1.4325842696629214,
#   'no_speech_prob': 0.34106191992759705},
#  {'id': 42,
#   'seek': 15608,
#   'start': 166.72000000000003,
#   'end': 168.96,
#   'text': ' Yes, exactly.',
#   'tokens': [50896, 1079, 11, 2293, 13, 51008],
#   'temperature': 0.0,
#   'avg_logprob': -0.3408244560504782,
#   'compression_ratio': 1.4325842696629214,
#   'no_speech_prob': 0.34106191992759705},
#  {'id': 43,
#   'seek': 15608,
#   'start': 168.96,
#   'end': 169.96,
#   'text': ' Thank you.',
#   'tokens': [51008, 1044, 291, 13, 51058],
#   'temperature': 0.0,
#   'avg_logprob': -0.3408244560504782,
#   'compression_ratio': 1.4325842696629214,
#   'no_speech_prob': 0.34106191992759705},
#  {'id': 44,
#   'seek': 15608,
#   'start': 169.96,
#   'end': 172.56,
#   'text': " Now what's the phone number that you put on the order before?",
#   'tokens': [51058,
#    823,
#    437,
#    311,
#    264,
#    2593,
#    1230,
#    300,
#    291,
#    829,
#    322,
#    264,
#    1668,
#    949,
#    30,
#    51188],
#   'temperature': 0.0,
#   'avg_logprob': -0.3408244560504782,
#   'compression_ratio': 1.4325842696629214,
#   'no_speech_prob': 0.34106191992759705},
#  {'id': 45,
#   'seek': 15608,
#   'start': 172.56,
#   'end': 181.12,
#   'text': " Okay, probably it's 411-3450377.",
#   'tokens': [51188,
#    1033,
#    11,
#    1391,
#    309,
#    311,
#    1017,
#    5348,
#    12,
#    12249,
#    2803,
#    12851,
#    22,
#    13,
#    51616],
#   'temperature': 0.0,
#   'avg_logprob': -0.3408244560504782,
#   'compression_ratio': 1.4325842696629214,
#   'no_speech_prob': 0.34106191992759705},
#  {'id': 46,
#   'seek': 15608,
#   'start': 181.12,
#   'end': 182.12,
#   'text': ' Thank you.',
#   'tokens': [51616, 1044, 291, 13, 51666],
#   'temperature': 0.0,
#   'avg_logprob': -0.3408244560504782,
#   'compression_ratio': 1.4325842696629214,
#   'no_speech_prob': 0.34106191992759705},
#  {'id': 47,
#   'seek': 18212,
#   'start': 182.12,
#   'end': 186.16,
#   'text': " So it's 411-3450377, is that correct?",
#   'tokens': [50364,
#    407,
#    309,
#    311,
#    1017,
#    5348,
#    12,
#    12249,
#    2803,
#    12851,
#    22,
#    11,
#    307,
#    300,
#    3006,
#    30,
#    50566],
#   'temperature': 0.0,
#   'avg_logprob': -0.2947117941720145,
#   'compression_ratio': 1.6795580110497237,
#   'no_speech_prob': 0.5553037524223328},
#  {'id': 48,
#   'seek': 18212,
#   'start': 186.16,
#   'end': 187.72,
#   'text': " Oh, it's 0377.",
#   'tokens': [50566, 876, 11, 309, 311, 1958, 12851, 22, 13, 50644],
#   'temperature': 0.0,
#   'avg_logprob': -0.2947117941720145,
#   'compression_ratio': 1.6795580110497237,
#   'no_speech_prob': 0.5553037524223328},
#  {'id': 49,
#   'seek': 18212,
#   'start': 187.72,
#   'end': 191.8,
#   'text': " Okay, and what's the email address that you gave when you fill out the order form?",
#   'tokens': [50644,
#    1033,
#    11,
#    293,
#    437,
#    311,
#    264,
#    3796,
#    2985,
#    300,
#    291,
#    2729,
#    562,
#    291,
#    2836,
#    484,
#    264,
#    1668,
#    1254,
#    30,
#    50848],
#   'temperature': 0.0,
#   'avg_logprob': -0.2947117941720145,
#   'compression_ratio': 1.6795580110497237,
#   'no_speech_prob': 0.5553037524223328},
#  {'id': 50,
#   'seek': 18212,
#   'start': 191.8,
#   'end': 200.12,
#   'text': ' Okay, that should be Adam underscore Wilson at mailfence.com.',
#   'tokens': [50848,
#    1033,
#    11,
#    300,
#    820,
#    312,
#    7938,
#    37556,
#    15388,
#    412,
#    10071,
#    69,
#    655,
#    13,
#    1112,
#    13,
#    51264],
#   'temperature': 0.0,
#   'avg_logprob': -0.2947117941720145,
#   'compression_ratio': 1.6795580110497237,
#   'no_speech_prob': 0.5553037524223328},
#  {'id': 51,
#   'seek': 18212,
#   'start': 200.12,
#   'end': 201.12,
#   'text': ' Thank you.',
#   'tokens': [51264, 1044, 291, 13, 51314],
#   'temperature': 0.0,
#   'avg_logprob': -0.2947117941720145,
#   'compression_ratio': 1.6795580110497237,
#   'no_speech_prob': 0.5553037524223328},
#  {'id': 52,
#   'seek': 18212,
#   'start': 201.12,
#   'end': 207.24,
#   'text': " So again, it's Adam underscore Wilson at mailfence.com, is that correct?",
#   'tokens': [51314,
#    407,
#    797,
#    11,
#    309,
#    311,
#    7938,
#    37556,
#    15388,
#    412,
#    10071,
#    69,
#    655,
#    13,
#    1112,
#    11,
#    307,
#    300,
#    3006,
#    30,
#    51620],
#   'temperature': 0.0,
#   'avg_logprob': -0.2947117941720145,
#   'compression_ratio': 1.6795580110497237,
#   'no_speech_prob': 0.5553037524223328},
#  {'id': 53,
#   'seek': 18212,
#   'start': 207.24,
#   'end': 208.96,
#   'text': ' Yes, it is.',
#   'tokens': [51620, 1079, 11, 309, 307, 13, 51706],
#   'temperature': 0.0,
#   'avg_logprob': -0.2947117941720145,
#   'compression_ratio': 1.6795580110497237,
#   'no_speech_prob': 0.5553037524223328},
#  {'id': 54,
#   'seek': 18212,
#   'start': 208.96,
#   'end': 209.96,
#   'text': ' Thank you.',
#   'tokens': [51706, 1044, 291, 13, 51756],
#   'temperature': 0.0,
#   'avg_logprob': -0.2947117941720145,
#   'compression_ratio': 1.6795580110497237,
#   'no_speech_prob': 0.5553037524223328},
#  {'id': 55,
#   'seek': 20996,
#   'start': 209.96,
#   'end': 216.36,
#   'text': ' So Adam underscore Wilson at mailfence.com.',
#   'tokens': [50364,
#    407,
#    7938,
#    37556,
#    15388,
#    412,
#    10071,
#    69,
#    655,
#    13,
#    1112,
#    13,
#    50684],
#   'temperature': 0.0,
#   'avg_logprob': -0.3692470505124047,
#   'compression_ratio': 1.453125,
#   'no_speech_prob': 0.061229951679706573},
#  {'id': 56,
#   'seek': 20996,
#   'start': 216.36,
#   'end': 218.16,
#   'text': ' Okay, thank you.',
#   'tokens': [50684, 1033, 11, 1309, 291, 13, 50774],
#   'temperature': 0.0,
#   'avg_logprob': -0.3692470505124047,
#   'compression_ratio': 1.453125,
#   'no_speech_prob': 0.061229951679706573},
#  {'id': 57,
#   'seek': 20996,
#   'start': 218.16,
#   'end': 221.20000000000002,
#   'text': ' Now I just want to make sure that I have the correct details.',
#   'tokens': [50774,
#    823,
#    286,
#    445,
#    528,
#    281,
#    652,
#    988,
#    300,
#    286,
#    362,
#    264,
#    3006,
#    4365,
#    13,
#    50926],
#   'temperature': 0.0,
#   'avg_logprob': -0.3692470505124047,
#   'compression_ratio': 1.453125,
#   'no_speech_prob': 0.061229951679706573},
#  {'id': 58,
#   'seek': 20996,
#   'start': 221.20000000000002,
#   'end': 225.28,
#   'text': ' Please hold on for a moment while we check on the details here in my end, okay?',
#   'tokens': [50926,
#    2555,
#    1797,
#    322,
#    337,
#    257,
#    1623,
#    1339,
#    321,
#    1520,
#    322,
#    264,
#    4365,
#    510,
#    294,
#    452,
#    917,
#    11,
#    1392,
#    30,
#    51130],
#   'temperature': 0.0,
#   'avg_logprob': -0.3692470505124047,
#   'compression_ratio': 1.453125,
#   'no_speech_prob': 0.061229951679706573},
#  {'id': 59,
#   'seek': 20996,
#   'start': 225.28,
#   'end': 227.4,
#   'text': ' Oh sure, no problem.',
#   'tokens': [51130, 876, 988, 11, 572, 1154, 13, 51236],
#   'temperature': 0.0,
#   'avg_logprob': -0.3692470505124047,
#   'compression_ratio': 1.453125,
#   'no_speech_prob': 0.061229951679706573},
#  {'id': 60,
#   'seek': 20996,
#   'start': 227.4,
#   'end': 229.4,
#   'text': ' All right.',
#   'tokens': [51236, 1057, 558, 13, 51336],
#   'temperature': 0.0,
#   'avg_logprob': -0.3692470505124047,
#   'compression_ratio': 1.453125,
#   'no_speech_prob': 0.061229951679706573},
#  {'id': 61,
#   'seek': 20996,
#   'start': 229.4,
#   'end': 236.4,
#   'text': ' Okay, thank you for patiently waiting, Adam.',
#   'tokens': [51336,
#    1033,
#    11,
#    1309,
#    291,
#    337,
#    49001,
#    3806,
#    11,
#    7938,
#    13,
#    51686],
#   'temperature': 0.0,
#   'avg_logprob': -0.3692470505124047,
#   'compression_ratio': 1.453125,
#   'no_speech_prob': 0.061229951679706573},
#  {'id': 62,
#   'seek': 23640,
#   'start': 236.4,
#   'end': 241.36,
#   'text': " Now I actually, or I can actually see here that you have called to inform us that you'd",
#   'tokens': [50364,
#    823,
#    286,
#    767,
#    11,
#    420,
#    286,
#    393,
#    767,
#    536,
#    510,
#    300,
#    291,
#    362,
#    1219,
#    281,
#    1356,
#    505,
#    300,
#    291,
#    1116,
#    50612],
#   'temperature': 0.0,
#   'avg_logprob': -0.19689266204833986,
#   'compression_ratio': 1.721951219512195,
#   'no_speech_prob': 0.4299549460411072},
#  {'id': 63,
#   'seek': 23640,
#   'start': 241.36,
#   'end': 246.04000000000002,
#   'text': ' like to return the item on the 15th of November.',
#   'tokens': [50612,
#    411,
#    281,
#    2736,
#    264,
#    3174,
#    322,
#    264,
#    2119,
#    392,
#    295,
#    7674,
#    13,
#    50846],
#   'temperature': 0.0,
#   'avg_logprob': -0.19689266204833986,
#   'compression_ratio': 1.721951219512195,
#   'no_speech_prob': 0.4299549460411072},
#  {'id': 64,
#   'seek': 23640,
#   'start': 246.04000000000002,
#   'end': 247.04000000000002,
#   'text': ' Is that correct?',
#   'tokens': [50846, 1119, 300, 3006, 30, 50896],
#   'temperature': 0.0,
#   'avg_logprob': -0.19689266204833986,
#   'compression_ratio': 1.721951219512195,
#   'no_speech_prob': 0.4299549460411072},
#  {'id': 65,
#   'seek': 23640,
#   'start': 247.04000000000002,
#   'end': 248.04000000000002,
#   'text': ' Yes.',
#   'tokens': [50896, 1079, 13, 50946],
#   'temperature': 0.0,
#   'avg_logprob': -0.19689266204833986,
#   'compression_ratio': 1.721951219512195,
#   'no_speech_prob': 0.4299549460411072},
#  {'id': 66,
#   'seek': 23640,
#   'start': 248.04000000000002,
#   'end': 253.88,
#   'text': ' Now did you return the item to the courier company on the same day that you called?',
#   'tokens': [50946,
#    823,
#    630,
#    291,
#    2736,
#    264,
#    3174,
#    281,
#    264,
#    1005,
#    811,
#    2237,
#    322,
#    264,
#    912,
#    786,
#    300,
#    291,
#    1219,
#    30,
#    51238],
#   'temperature': 0.0,
#   'avg_logprob': -0.19689266204833986,
#   'compression_ratio': 1.721951219512195,
#   'no_speech_prob': 0.4299549460411072},
#  {'id': 67,
#   'seek': 23640,
#   'start': 253.88,
#   'end': 257.36,
#   'text': ' Probably close to it.',
#   'tokens': [51238, 9210, 1998, 281, 309, 13, 51412],
#   'temperature': 0.0,
#   'avg_logprob': -0.19689266204833986,
#   'compression_ratio': 1.721951219512195,
#   'no_speech_prob': 0.4299549460411072},
#  {'id': 68,
#   'seek': 23640,
#   'start': 257.36,
#   'end': 262.8,
#   'text': " I'm not really sure if it's on the same day though, but probably just close to that day.",
#   'tokens': [51412,
#    286,
#    478,
#    406,
#    534,
#    988,
#    498,
#    309,
#    311,
#    322,
#    264,
#    912,
#    786,
#    1673,
#    11,
#    457,
#    1391,
#    445,
#    1998,
#    281,
#    300,
#    786,
#    13,
#    51684],
#   'temperature': 0.0,
#   'avg_logprob': -0.19689266204833986,
#   'compression_ratio': 1.721951219512195,
#   'no_speech_prob': 0.4299549460411072},
#  {'id': 69,
#   'seek': 26280,
#   'start': 262.8,
#   'end': 263.8,
#   'text': ' I understand.',
#   'tokens': [50364, 286, 1223, 13, 50414],
#   'temperature': 0.0,
#   'avg_logprob': -0.14676270661530672,
#   'compression_ratio': 1.653386454183267,
#   'no_speech_prob': 0.30683696269989014},
#  {'id': 70,
#   'seek': 26280,
#   'start': 263.8,
#   'end': 270.6,
#   'text': " However, upon checking the date that you actually called in for the return, it's already beyond",
#   'tokens': [50414,
#    2908,
#    11,
#    3564,
#    8568,
#    264,
#    4002,
#    300,
#    291,
#    767,
#    1219,
#    294,
#    337,
#    264,
#    2736,
#    11,
#    309,
#    311,
#    1217,
#    4399,
#    50754],
#   'temperature': 0.0,
#   'avg_logprob': -0.14676270661530672,
#   'compression_ratio': 1.653386454183267,
#   'no_speech_prob': 0.30683696269989014},
#  {'id': 71,
#   'seek': 26280,
#   'start': 270.6,
#   'end': 273.40000000000003,
#   'text': ' the time frame that we asked for refunds.',
#   'tokens': [50754, 264, 565, 3920, 300, 321, 2351, 337, 29384, 82, 13, 50894],
#   'temperature': 0.0,
#   'avg_logprob': -0.14676270661530672,
#   'compression_ratio': 1.653386454183267,
#   'no_speech_prob': 0.30683696269989014},
#  {'id': 72,
#   'seek': 26280,
#   'start': 273.40000000000003,
#   'end': 278.52000000000004,
#   'text': " So what we'll do is go ahead and forward this information to our corporate office and I'll",
#   'tokens': [50894,
#    407,
#    437,
#    321,
#    603,
#    360,
#    307,
#    352,
#    2286,
#    293,
#    2128,
#    341,
#    1589,
#    281,
#    527,
#    10896,
#    3398,
#    293,
#    286,
#    603,
#    51150],
#   'temperature': 0.0,
#   'avg_logprob': -0.14676270661530672,
#   'compression_ratio': 1.653386454183267,
#   'no_speech_prob': 0.30683696269989014},
#  {'id': 73,
#   'seek': 26280,
#   'start': 278.52000000000004,
#   'end': 281.6,
#   'text': ' have them check and update you directly about the refund.',
#   'tokens': [51150,
#    362,
#    552,
#    1520,
#    293,
#    5623,
#    291,
#    3838,
#    466,
#    264,
#    29384,
#    13,
#    51304],
#   'temperature': 0.0,
#   'avg_logprob': -0.14676270661530672,
#   'compression_ratio': 1.653386454183267,
#   'no_speech_prob': 0.30683696269989014},
#  {'id': 74,
#   'seek': 26280,
#   'start': 281.6,
#   'end': 285.56,
#   'text': ' So please expect an email within two to four business days.',
#   'tokens': [51304,
#    407,
#    1767,
#    2066,
#    364,
#    3796,
#    1951,
#    732,
#    281,
#    1451,
#    1606,
#    1708,
#    13,
#    51502],
#   'temperature': 0.0,
#   'avg_logprob': -0.14676270661530672,
#   'compression_ratio': 1.653386454183267,
#   'no_speech_prob': 0.30683696269989014},
#  {'id': 75,
#   'seek': 26280,
#   'start': 285.56,
#   'end': 287.04,
#   'text': ' Is that okay with you?',
#   'tokens': [51502, 1119, 300, 1392, 365, 291, 30, 51576],
#   'temperature': 0.0,
#   'avg_logprob': -0.14676270661530672,
#   'compression_ratio': 1.653386454183267,
#   'no_speech_prob': 0.30683696269989014},
#  {'id': 76,
#   'seek': 26280,
#   'start': 287.04,
#   'end': 288.84000000000003,
#   'text': ' Two to four business days?',
#   'tokens': [51576, 4453, 281, 1451, 1606, 1708, 30, 51666],
#   'temperature': 0.0,
#   'avg_logprob': -0.14676270661530672,
#   'compression_ratio': 1.653386454183267,
#   'no_speech_prob': 0.30683696269989014},
#  {'id': 77,
#   'seek': 26280,
#   'start': 288.84000000000003,
#   'end': 289.84000000000003,
#   'text': ' Yes.',
#   'tokens': [51666, 1079, 13, 51716],
#   'temperature': 0.0,
#   'avg_logprob': -0.14676270661530672,
#   'compression_ratio': 1.653386454183267,
#   'no_speech_prob': 0.30683696269989014},
#  {'id': 78,
#   'seek': 28984,
#   'start': 289.84,
#   'end': 290.84,
#   'text': ' No worries.',
#   'tokens': [50364, 883, 16340, 13, 50414],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 79,
#   'seek': 28984,
#   'start': 290.84,
#   'end': 292.84,
#   'text': ' I will send it to them right now.',
#   'tokens': [50414, 286, 486, 2845, 309, 281, 552, 558, 586, 13, 50514],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 80,
#   'seek': 28984,
#   'start': 292.84,
#   'end': 293.84,
#   'text': ' Oh really?',
#   'tokens': [50514, 876, 534, 30, 50564],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 81,
#   'seek': 28984,
#   'start': 293.84,
#   'end': 294.84,
#   'text': ' Okay.',
#   'tokens': [50564, 1033, 13, 50614],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 82,
#   'seek': 28984,
#   'start': 294.84,
#   'end': 295.84,
#   'text': ' All right.',
#   'tokens': [50614, 1057, 558, 13, 50664],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 83,
#   'seek': 28984,
#   'start': 295.84,
#   'end': 296.84,
#   'text': ' All right.',
#   'tokens': [50664, 1057, 558, 13, 50714],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 84,
#   'seek': 28984,
#   'start': 296.84,
#   'end': 299.84,
#   'text': ' At first I thought that it will probably be like three to five weeks to process.',
#   'tokens': [50714,
#    1711,
#    700,
#    286,
#    1194,
#    300,
#    309,
#    486,
#    1391,
#    312,
#    411,
#    1045,
#    281,
#    1732,
#    3259,
#    281,
#    1399,
#    13,
#    50864],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 85,
#   'seek': 28984,
#   'start': 299.84,
#   'end': 301.64,
#   'text': ' Oh, no, no, no, no.',
#   'tokens': [50864, 876, 11, 572, 11, 572, 11, 572, 11, 572, 13, 50954],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 86,
#   'seek': 28984,
#   'start': 301.64,
#   'end': 302.64,
#   'text': " Don't worry, Adam.",
#   'tokens': [50954, 1468, 380, 3292, 11, 7938, 13, 51004],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 87,
#   'seek': 28984,
#   'start': 302.64,
#   'end': 305.15999999999997,
#   'text': " It's only two to four business days.",
#   'tokens': [51004, 467, 311, 787, 732, 281, 1451, 1606, 1708, 13, 51130],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 88,
#   'seek': 28984,
#   'start': 305.15999999999997,
#   'end': 309.28,
#   'text': ' So you already checked your account and nothing has been credited yet on the card ending in',
#   'tokens': [51130,
#    407,
#    291,
#    1217,
#    10033,
#    428,
#    2696,
#    293,
#    1825,
#    575,
#    668,
#    41155,
#    1939,
#    322,
#    264,
#    2920,
#    8121,
#    294,
#    51336],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 89,
#   'seek': 28984,
#   'start': 309.28,
#   'end': 310.76,
#   'text': ' seven, five, three.',
#   'tokens': [51336, 3407, 11, 1732, 11, 1045, 13, 51410],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 90,
#   'seek': 28984,
#   'start': 310.76,
#   'end': 311.76,
#   'text': ' Is that right?',
#   'tokens': [51410, 1119, 300, 558, 30, 51460],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 91,
#   'seek': 28984,
#   'start': 311.76,
#   'end': 312.76,
#   'text': ' Not yet.',
#   'tokens': [51460, 1726, 1939, 13, 51510],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 92,
#   'seek': 28984,
#   'start': 312.76,
#   'end': 313.76,
#   'text': ' Okay.',
#   'tokens': [51510, 1033, 13, 51560],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 93,
#   'seek': 28984,
#   'start': 313.76,
#   'end': 314.76,
#   'text': ' Understand.',
#   'tokens': [51560, 26093, 13, 51610],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 94,
#   'seek': 28984,
#   'start': 314.76,
#   'end': 319.32,
#   'text': " And I'll go ahead and forward them to the, forward in the details that I have here.",
#   'tokens': [51610,
#    400,
#    286,
#    603,
#    352,
#    2286,
#    293,
#    2128,
#    552,
#    281,
#    264,
#    11,
#    2128,
#    294,
#    264,
#    4365,
#    300,
#    286,
#    362,
#    510,
#    13,
#    51838],
#   'temperature': 0.0,
#   'avg_logprob': -0.2026811292094569,
#   'compression_ratio': 1.6517241379310346,
#   'no_speech_prob': 0.09163405001163483},
#  {'id': 95,
#   'seek': 31932,
#   'start': 319.32,
#   'end': 325.44,
#   'text': ' You will send the email to adam underscore Wilson at mailfence.com, correct?',
#   'tokens': [50364,
#    509,
#    486,
#    2845,
#    264,
#    3796,
#    281,
#    16368,
#    37556,
#    15388,
#    412,
#    10071,
#    69,
#    655,
#    13,
#    1112,
#    11,
#    3006,
#    30,
#    50670],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 96,
#   'seek': 31932,
#   'start': 325.44,
#   'end': 326.44,
#   'text': " Yes, that's right.",
#   'tokens': [50670, 1079, 11, 300, 311, 558, 13, 50720],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 97,
#   'seek': 31932,
#   'start': 326.44,
#   'end': 327.44,
#   'text': ' All right.',
#   'tokens': [50720, 1057, 558, 13, 50770],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 98,
#   'seek': 31932,
#   'start': 327.44,
#   'end': 329.84,
#   'text': ' Thank you so much for that information, Adam.',
#   'tokens': [50770, 1044, 291, 370, 709, 337, 300, 1589, 11, 7938, 13, 50890],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 99,
#   'seek': 31932,
#   'start': 329.84,
#   'end': 335.4,
#   'text': ' I will be forwarding this over to our corporate office now and thank you again for calling',
#   'tokens': [50890,
#    286,
#    486,
#    312,
#    2128,
#    278,
#    341,
#    670,
#    281,
#    527,
#    10896,
#    3398,
#    586,
#    293,
#    1309,
#    291,
#    797,
#    337,
#    5141,
#    51168],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 100,
#   'seek': 31932,
#   'start': 335.4,
#   'end': 336.48,
#   'text': ' Cops and Gowns.',
#   'tokens': [51168, 383, 3370, 293, 460, 648, 82, 13, 51222],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 101,
#   'seek': 31932,
#   'start': 336.48,
#   'end': 338.6,
#   'text': ' Is there anything else I can help you with today?',
#   'tokens': [51222,
#    1119,
#    456,
#    1340,
#    1646,
#    286,
#    393,
#    854,
#    291,
#    365,
#    965,
#    30,
#    51328],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 102,
#   'seek': 31932,
#   'start': 338.6,
#   'end': 340.6,
#   'text': " Oh no, that's all.",
#   'tokens': [51328, 876, 572, 11, 300, 311, 439, 13, 51428],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 103,
#   'seek': 31932,
#   'start': 340.6,
#   'end': 341.6,
#   'text': ' Thank you.',
#   'tokens': [51428, 1044, 291, 13, 51478],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 104,
#   'seek': 31932,
#   'start': 341.6,
#   'end': 343.36,
#   'text': " You're welcome and my pleasure.",
#   'tokens': [51478, 509, 434, 2928, 293, 452, 6834, 13, 51566],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 105,
#   'seek': 31932,
#   'start': 343.36,
#   'end': 344.36,
#   'text': ' Have a nice day.',
#   'tokens': [51566, 3560, 257, 1481, 786, 13, 51616],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 106,
#   'seek': 31932,
#   'start': 344.36,
#   'end': 345.36,
#   'text': ' Bye.',
#   'tokens': [51616, 4621, 13, 51666],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 107,
#   'seek': 31932,
#   'start': 345.36,
#   'end': 346.36,
#   'text': ' All right.',
#   'tokens': [51666, 1057, 558, 13, 51716],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126},
#  {'id': 108,
#   'seek': 31932,
#   'start': 346.36,
#   'end': 346.4,
#   'text': ' Thank you.',
#   'tokens': [51716, 1044, 291, 13, 51718],
#   'temperature': 0.0,
#   'avg_logprob': -0.2450523954449278,
#   'compression_ratio': 1.62109375,
#   'no_speech_prob': 0.2742362320423126}]

# %%
transcript=diarize(wav_file, result)

# %%
transcript
# Out:
#       Speaker                                               Text Time Start  \
# 0   SPEAKER 1   Thank you for calling Coats and Gounds, my na...   00:00:00
# 1   SPEAKER 2   Seems like it does not apply to my account ye...   00:00:31
# 2   SPEAKER 1   Alright, please wait for a moment. Okay, hold...   00:00:44
# 3   SPEAKER 2   Just to verify that 017 1425 793, correct? Ye...   00:00:57
# 4   SPEAKER 1    Yeah, I'm not sure about a 07 or 3.0 something.   00:01:23
# 5   SPEAKER 2   Anyway, it's Adam Wilson. Alright, thank you....   00:01:28
# 6   SPEAKER 1                         Not sure. Is it the 74391?   00:01:58
# 7   SPEAKER 2   That's actually the return authorization from...   00:02:04
# 8   SPEAKER 1   Okay, I probably have to dig it up. Okay, I i...   00:02:19
# 9   SPEAKER 2   Anyway, I tried to search for your name and n...   00:02:33
# 10  SPEAKER 1                           Yes, yes, enter my name.   00:02:40
# 11  SPEAKER 2   So it's not under Andy or something, it's Ada...   00:02:43
# 12  SPEAKER 1                   Okay, probably it's 411-3450377.   00:02:53
# 13  SPEAKER 2   Thank you. So it's 411-3450377, is that corre...   00:03:01
# 14  SPEAKER 1   Okay, that should be Adam underscore Wilson a...   00:03:12
# 15  SPEAKER 2   So again, it's Adam underscore Wilson at mail...   00:03:21
# 16  SPEAKER 1                                        Yes, it is.   00:03:27
# 17  SPEAKER 2   Thank you. So Adam underscore Wilson at mailf...   00:03:29
# 18  SPEAKER 1                    Oh sure, no problem. All right.   00:03:45
# 19  SPEAKER 2   Okay, thank you for patiently waiting, Adam. ...   00:03:49
# 20  SPEAKER 1                                               Yes.   00:04:07
# 21  SPEAKER 2   Now did you return the item to the courier co...   00:04:08
# 22  SPEAKER 1   Probably close to it. I'm not really sure if ...   00:04:14
# 23  SPEAKER 2   I understand. However, upon checking the date...   00:04:23
# 24  SPEAKER 1                                        No worries.   00:04:50
# 25  SPEAKER 2                  I will send it to them right now.   00:04:51
# 26  SPEAKER 1                                         Oh really?   00:04:53
# 27  SPEAKER 2                                              Okay.   00:04:54
# 28  SPEAKER 1   All right. All right. At first I thought that...   00:04:55
# 29  SPEAKER 2   Don't worry, Adam. It's only two to four busi...   00:05:02
# 30  SPEAKER 1                                           Not yet.   00:05:12
# 31  SPEAKER 2   Okay. Understand. And I'll go ahead and forwa...   00:05:13
# 32  SPEAKER 1                      Oh no, that's all. Thank you.   00:05:39
# 33  SPEAKER 2   You're welcome and my pleasure. Have a nice day.   00:05:42
# 34  SPEAKER 1                         Bye. All right. Thank you.   00:05:44
#
#     Time End
# 0   00:00:24
# 1   00:00:43
# 2   00:00:56
# 3   00:01:21
# 4   00:01:23
# 5   00:01:51
# 6   00:01:59
# 7   00:02:16
# 8   00:02:31
# 9   00:02:36
# 10  00:02:40
# 11  00:02:50
# 12  00:02:53
# 13  00:03:08
# 14  00:03:20
# 15  00:03:21
# 16  00:03:27
# 17  00:03:41
# 18  00:03:47
# 19  00:04:06
# 20  00:04:07
# 21  00:04:08
# 22  00:04:17
# 23  00:04:49
# 24  00:04:50
# 25  00:04:51
# 26  00:04:53
# 27  00:04:54
# 28  00:05:00
# 29  00:05:11
# 30  00:05:12
# 31  00:05:36
# 32  00:05:41
# 33  00:05:43
# 34  00:05:46

# %%
makecsv(wav_file, transcript)
